# %%
import pandas as pd
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
import torch.nn.functional as f 
from torch.autograd import Variable
torch.backends.cudnn.deterministic = True
import numpy as np
import torch.utils.data as data_utils
import random 
from matplotlib import pyplot as plt
import sys
import utilities as ut
from Network import Net
import Network as nn
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

batch_size = 256
hidden_size = 100
num_classes = 2
# Out:
# /home/franciscoperez/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/franciscoperez/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
pd.read_csv('13_01_2023_gaussian2d.csv').sort_values('acc_test', ascending=False).head(5)
# Out:
#     Unnamed: 0  acc_train   acc_test  recall_train  recall_test  f1_train  \
# 26          26  99.876190  82.247920      0.999557     0.888126  0.999159
# 9            9  99.929070  82.139850      0.999246     0.854389  0.999269
# 20          20  99.907120  82.115570      0.999734     0.863371  0.999403
# 2            2  99.867546  81.307396      0.999558     0.872864  0.999117
# 15          15  99.884705  81.280590      0.999601     0.849131  0.999224
#
#      f1_test  roc_train  roc_test  epsilon  batch_size  hidden_size  \
# 26  0.854043   0.999124  0.892750        0         256          100
# 9   0.837569   0.999373  0.879369        0         256          100
# 20  0.841734   0.999259  0.876956        0         256          100
# 2   0.841909   0.998952  0.873357        0         256          100
# 15  0.830572   0.999119  0.870377        0         256          100
#
#     aux_loss_activated   EPS1      n  opt
# 26                True  0.025  50000    1
# 9                 True  0.025  50000    1
# 20                True  0.025  50000    1
# 2                 True  0.025  50000    1
# 15                True  0.025  50000    1

# %%
pd.read_csv('13_01_2023_baseline.csv').sort_values('acc_test', ascending=False).head(5)
# Out:
#     Unnamed: 0  acc_train  acc_test  recall_train  recall_test  f1_train  \
# 26          26  99.889800  81.44302      0.999162     0.881992  0.999030
# 18          18  99.902610  79.44064      0.999601     0.898131  0.999314
# 3            3  99.893870  79.36625      0.999469     0.865123  0.999204
# 11          11  99.907110  79.35332      0.999425     0.883526  0.999248
# 15          15  99.920395  79.10737      0.999646     0.864612  0.999425
#
#      f1_test  roc_train  roc_test  epsilon  batch_size  hidden_size  \
# 26  0.846866   0.999148  0.875753      0.2         256          100
# 18  0.843090   0.999293  0.866602      0.2         256          100
# 3   0.827854   0.999059  0.855890      0.2         256          100
# 11  0.836115   0.999115  0.863383      0.2         256          100
# 15  0.826210   0.999324  0.856055      0.2         256          100
#
#     aux_loss_activated   EPS1      n  opt
# 26               False  0.025  50000    2
# 18               False  0.025  50000    2
# 3                False  0.025  50000    2
# 11               False  0.025  50000    2
# 15               False  0.025  50000    2

# %%
datContent = [i.strip().split() for i in open("../paper2-pending/subclasses/ident1.dat").readlines()]

data = pd.DataFrame(datContent)
data.columns = ['ID', 'field_a','field_b', 'sub_clase', 'ccx', 'ccy', 'd', 'e', 'f', 'g' ]
data=data[['ID', 'field_a','field_b', 'sub_clase', 'ccx', 'ccy']]
data.shape

datContent = [i.strip().split() for i in open("../paper2-pending/subclasses/ident2.dat").readlines()]

data2 = pd.DataFrame(datContent)
data2.columns = ['ID', 'field_a','field_b', 'sub_clase', 'ccx', 'ccy']
data = data.append(data2)
data.shape

datContent = [i.strip().split() for i in open("../paper2-pending/subclasses/ident3.dat").readlines()]

data3 = pd.DataFrame(datContent)
data3.columns = ['ID', 'field_a','field_b', 'sub_clase', 'ccx', 'ccy', 'd', 'e', 'f', 'g' ,'k']
data3=data3[['ID', 'field_a','field_b', 'sub_clase', 'ccx', 'ccy']]
data = data.append(data3)
data.shape

datContent = [i.strip().split() for i in open("../paper2-pending/subclasses/ident4.dat").readlines()]

data4 = pd.DataFrame(datContent)
data4.columns = ['ID', 'field_a','field_b', 'sub_clase', 'ccx', 'ccy', 'd', 'e', 'f', 'g' ]
data4=data4[['ID', 'field_a','field_b', 'sub_clase', 'ccx', 'ccy']]
data = data.append(data4)
data.shape


data = data[data.sub_clase.isin(['RRab', 'RRd', 'RRc', 'RRe'])]

# %%
def filter_by_subclass(data_subclasses, subclass='RRab'): 
    path_test = '/home/franciscoperez/Documents/GitHub/data/BIASEDFATS/Test_rrlyr-1.csv'
    lc_test = pd.read_table(path_test, sep= ',')
    del lc_test['Unnamed: 0']
    columns_to_export = lc_test.columns
    lc_test['ID'] = lc_test['ID'].str.replace('.dat', '') 
    lc_test = lc_test.merge(data_subclasses, left_on='ID', right_on='ID', how = 'left')
    lc_test = lc_test[lc_test.sub_clase==subclass]
    return lc_test[columns_to_export]

RRab_test = filter_by_subclass(data, subclass='RRab')
RRc_test = filter_by_subclass(data, subclass='RRc')
RRd_test = filter_by_subclass(data, subclass='RRd')
RRe_test = filter_by_subclass(data, subclass='RRe')
# Out:
# /home/franciscoperez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
train_dataset, test_dataset = ut.load_files(dataset=1)
train_dataset.head()
# Out:
# Freq1_harmonics_rel_phase_0
# Freq2_harmonics_rel_phase_0
# Freq3_harmonics_rel_phase_0
#         Amplitude  AndersonDarling  Autocor_length  Beyond1Std   CAR_mean  \
# 49643      0.0435         0.131166               3    0.326667  23.686214
# 407286     0.0205         0.457675               3    0.270000  54.028838
# 106019     0.0305         0.842306               4    0.258065  18.163004
# 269038     0.0175         0.113156               2    0.350000  35.016108
# 333084     0.0150         0.007341               1    0.273973  34.429653
#
#         CAR_sigma   CAR_tau       Con         Eta_e  FluxPercentileRatioMid20  \
# 49643    0.738367  0.594257  0.003356     77.820389                  0.191176
# 407286   0.549494  0.244528  0.003356     50.714320                  0.171429
# 106019   0.668703  0.655423  0.000000      6.988632                  0.120690
# 269038   0.405370  0.435593  0.006711  36098.082750                  0.137931
# 333084   0.733305  0.449642  0.000000     74.510326                  0.130435
#
#         ...      Skew  SlottedA_length  SmallKurtosis       Std  StetsonK  \
# 49643   ...  0.104165          0.12345      -0.098630  0.022427  0.816054
# 407286  ... -0.195980          2.96080       0.590754  0.010581  0.781576
# 106019  ...  0.115857          7.18960       0.061644  0.015522  0.792800
# 269038  ... -0.096889          4.04488       0.298335  0.009146  0.793050
# 333084  ... -0.178951          0.11075       0.838739  0.007203  0.770452
#
#         StetsonK_AC  StructureFunction_index_21  StructureFunction_index_31  \
# 49643      0.779717                    1.644229                    2.212875
# 407286     0.702489                    1.650383                    2.080388
# 106019     0.772128                    1.760809                    2.357977
# 269038     0.734278                    1.879023                    2.721291
# 333084     0.706294                    1.735545                    2.338960
#
#         StructureFunction_index_32   label
# 49643                     1.435421  ClassB
# 407286                    1.284226  ClassB
# 106019                    1.384309  ClassB
# 269038                    1.499985  ClassB
# 333084                    1.432837  ClassB
#
# [5 rows x 61 columns]

# %%
RRe_test[train_dataset.columns].head()
# Out:
#      Amplitude  AndersonDarling  Autocor_length  Beyond1Std    CAR_mean  \
# 16     0.16750         0.018003               1    0.303333   26.158132
# 27     0.22550         0.011021               1    0.296667  129.958025
# 164    0.14700         0.037791               1    0.351171   40.168090
# 352    0.22600         0.224821               1    0.313333   37.115196
# 365    0.19975         0.084151               1    0.295302  140.819375
#
#      CAR_sigma   CAR_tau  Con          Eta_e  FluxPercentileRatioMid20  ...  \
# 16    0.073465  0.725973  0.0      12.579577                  0.150000  ...
# 27    0.513429  0.148121  0.0  145609.518248                  0.178660  ...
# 164   0.114340  0.468277  0.0    1161.629293                  0.154762  ...
# 352   0.683457  0.522459  0.0      87.191250                  0.171662  ...
# 365   0.270730  0.135191  0.0     140.681435                  0.148485  ...
#
#          Skew  SlottedA_length  SmallKurtosis       Std  StetsonK  \
# 16   0.341465          1.96797       0.198594  0.078668  0.790933
# 27   0.460641          0.01650       0.551941  0.126372  0.822407
# 164  0.234766          0.04988      -0.267603  0.079077  0.827947
# 352  0.334666          1.95611       0.296205  0.115745  0.805037
# 365  0.551426          0.20806       1.326243  0.100128  0.797293
#
#      StetsonK_AC  StructureFunction_index_21  StructureFunction_index_31  \
# 16      0.664890                    2.078430                    3.183539
# 27      0.766745                    2.038494                    3.106660
# 164     0.863374                    1.854792                    2.734859
# 352     0.666054                    1.565646                    1.875291
# 365     0.784578                    1.978843                    2.951971
#
#      StructureFunction_index_32   label
# 16                     1.561949  ClassA
# 27                     1.544758  ClassA
# 164                    1.555903  ClassA
# 352                    1.336562  ClassA
# 365                    1.585350  ClassA
#
# [5 rows x 61 columns]

# %%
num_classes = 2
learning_rate = 0.005
samples = 3000
epsilon=0
results = []
#for epsilon in [0.1, 0.05, 0.025, 0.15]:
for batch_size in [256]:
    for hidden_size in [100]:
        for aux_loss_activated in [True, False]:
            for EPS1 in [0.025]:
                for n in [50000]:
                    for opt in [1]:
                        for t in range(10):
                            train_dataset, test_dataset = ut.load_files(dataset=1)
                            test_dataseta  = RRab_test[train_dataset.columns]
                            print(test_dataset.shape)
                            test_dataset = pd.concat([train_dataset[train_dataset.label=='ClassB'], test_dataseta])
                            print(test_dataset.shape)
                            test_dataset['random'] = np.random.random(test_dataset.shape[0])
                            test_dataset = test_dataset.sort_values('random')
                            del test_dataset['random']
                            input_size = train_dataset.shape[1]-1
                            train_dataset, test_dataset = ut.delete_outliers(train_dataset, test_dataset)
                            if n < 50000:
                                train_dataset = ut.down_sampling(train_dataset)
                                train_dataset = train_dataset.sample(n)
                            else: 
                                trainig_dataset_a = train_dataset[train_dataset.label=='ClassA']
                                n2 = n - trainig_dataset_a.shape[0]
                                trainig_dataset_b = train_dataset[~(train_dataset.label=='ClassA')].sample(n2)
                                train_dataset = pd.concat([trainig_dataset_a, trainig_dataset_b])
                            
                            train_dataset = ut.sort_columns(train_dataset)
                            test_dataset = ut.sort_columns(test_dataset)
                            test_dataset_pred = test_dataset.copy()
                            train_dataset_pred = train_dataset.copy()

                            data_prior = ut.generate_samples_2D(samples, train_dataset, distribution='gaussian')
                            if train_dataset[train_dataset.label=='ClassB'].shape[0] >= samples:
                                samples_prior = samples 
                            else: 
                                samples_prior = train_dataset[train_dataset.label=='ClassB'].shape[0] 

                            data_prior = pd.concat([data_prior, train_dataset[train_dataset.label=='ClassB'].sample(samples_prior)])


                            train_dataset, test_dataset, data_prior = ut.normalize(train_dataset, test_dataset, data_prior)

                            train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.2)

                            train_dataset_prior, val_dataset_prior = train_test_split(data_prior, test_size=0.2)
                            _, _, train_target_prior, train_loader_prior = ut.get_tensors(train_dataset_prior, batch_size)
                            _, _, val_target_prior, val_loader_prior     = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, train_target, train_loader             = ut.get_tensors(train_dataset, batch_size)
                            _, _, train_target_pred, train_loader_pred   = ut.get_tensors(train_dataset_pred, batch_size)
                            _, _, val_target, val_loader                 = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, test_target, test_loader               = ut.get_tensors(test_dataset, batch_size)
                            _, _, test_target_pred, test_loader_pred     = ut.get_tensors(test_dataset_pred, batch_size)

                            net = Net(input_size, hidden_size, hidden_size, num_classes)
                            net.cuda()

                            hist_val, hist_train, _ = nn.train(net, train_loader, train_loader_prior, val_loader, test_loader,
                            EPS1, learning_rate, input_size, aux_loss_activated=aux_loss_activated, model_number=t, size=n)

                            acc_train, recall_train, f1_train = nn.get_results(net, train_loader, input_size)
                            acc_test, recall_test, f1_test  = nn.get_results(net, test_loader, input_size)
                            roc_train = nn.get_roc_curve(net, train_loader, input_size)
                            roc_test = nn.get_roc_curve(net, test_loader, input_size)
                            results.append([acc_train, acc_test,recall_train, recall_test, f1_train, f1_test, roc_train, roc_test, epsilon, batch_size, hidden_size, aux_loss_activated, EPS1, n, opt])

                            pd.DataFrame(results, columns=['acc_train', 'acc_test','recall_train', 'recall_test','f1_train', 'f1_test', 
                                   'roc_train', 'roc_test', 'epsilon', 'batch_size', 'hidden_size',
                             'aux_loss_activated', 'EPS1', 'n', 'opt']).to_csv('RRab_17_01_2023_subclasses_gaussian2d.csv')
# Out:
# Freq1_harmonics_rel_phase_0
# Freq2_harmonics_rel_phase_0
# Freq3_harmonics_rel_phase_0
# ____get_tensor_function____
# shape tensor:  torch.Size([4792, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([1199, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([40000, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([50000, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([1199, 60])
# ____get_tensor_function____
# /home/franciscoperez/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# shape tensor:  torch.Size([353747, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([353747, 60])
# training: epoch:  1  loss:  55.59072944521904 -- aux loss:  16.644847452640533
# training: epoch:  2  loss:  50.79481041431427 -- aux loss:  14.00379130244255
# training: epoch:  3  loss:  50.559997260570526 -- aux loss:  9.296149879693985
# training: epoch:  4  loss:  50.39976167678833 -- aux loss:  10.802129358053207
# training: epoch:  5  loss:  50.31632772088051 -- aux loss:  7.977592915296555
# training: epoch:  6  loss:  50.27813160419464 -- aux loss:  7.864018499851227
# training: epoch:  7  loss:  50.24399471282959 -- aux loss:  8.680544912815094
# training: epoch:  8  loss:  50.228206127882004 -- aux loss:  7.6223339438438416
# training: epoch:  9  loss:  50.15829512476921 -- aux loss:  6.960376441478729
# training: epoch:  10  loss:  50.201079696416855 -- aux loss:  7.302032649517059
# the_last_loss:  0.0
# running_loss_val:  0.33505505323410034
# validating: epoch:  10  loss:  0.33505505323410034
# The current loss: 0.33505505323410034
# the_last_loss: 0.0
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  11  loss:  50.11301797628403 -- aux loss:  7.782855212688446
# training: epoch:  12  loss:  50.071461886167526 -- aux loss:  6.45962181687355
# training: epoch:  13  loss:  50.044992834329605 -- aux loss:  7.774164259433746
# training: epoch:  14  loss:  50.00187349319458 -- aux loss:  6.762895315885544
# training: epoch:  15  loss:  50.059349209070206 -- aux loss:  6.562137305736542
# training: epoch:  16  loss:  49.98346358537674 -- aux loss:  6.736290127038956
# training: epoch:  17  loss:  49.90259522199631 -- aux loss:  6.559870928525925
# training: epoch:  18  loss:  49.97616767883301 -- aux loss:  6.615321099758148
# training: epoch:  19  loss:  49.97232788801193 -- aux loss:  6.603479892015457
# training: epoch:  20  loss:  49.949712336063385 -- aux loss:  6.997520804405212
# the_last_loss:  0.33505505323410034
# running_loss_val:  0.47038617730140686
# validating: epoch:  20  loss:  0.47038617730140686
# The current loss: 0.47038617730140686
# the_last_loss: 0.33505505323410034
# trigger times: 2
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  21  loss:  49.902303636074066 -- aux loss:  6.633821874856949
# training: epoch:  22  loss:  49.86516147851944 -- aux loss:  6.578786879777908
# training: epoch:  23  loss:  49.83683285117149 -- aux loss:  6.518973410129547
# training: epoch:  24  loss:  49.82911288738251 -- aux loss:  6.45655831694603
# training: epoch:  25  loss:  49.8878310918808 -- aux loss:  6.421369820833206
# training: epoch:  26  loss:  49.83354231715202 -- aux loss:  6.463765114545822
# training: epoch:  27  loss:  49.798987329006195 -- aux loss:  6.412033975124359
# training: epoch:  28  loss:  49.78877234458923 -- aux loss:  6.292128771543503
# training: epoch:  29  loss:  49.813547879457474 -- aux loss:  6.394739925861359
# training: epoch:  30  loss:  49.830834567546844 -- aux loss:  6.219548523426056
# the_last_loss:  0.47038617730140686
# running_loss_val:  0.3190157115459442
# validating: epoch:  30  loss:  0.3190157115459442
# The current loss: 0.3190157115459442
# the_last_loss: 0.47038617730140686
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  31  loss:  49.72783452272415 -- aux loss:  6.387511432170868
# training: epoch:  32  loss:  49.820017635822296 -- aux loss:  6.640274167060852
# training: epoch:  33  loss:  49.71904098987579 -- aux loss:  6.2664168775081635
# training: epoch:  34  loss:  49.76325109601021 -- aux loss:  6.254553377628326
# training: epoch:  35  loss:  49.73793086409569 -- aux loss:  6.561246782541275
# training: epoch:  36  loss:  49.73641178011894 -- aux loss:  6.306237518787384
# training: epoch:  37  loss:  49.734256744384766 -- aux loss:  6.157347947359085
# training: epoch:  38  loss:  49.73178118467331 -- aux loss:  6.167242646217346
# training: epoch:  39  loss:  49.682014018297195 -- aux loss:  6.12121120095253
# training: epoch:  40  loss:  49.73785585165024 -- aux loss:  6.039224743843079
# the_last_loss:  0.3190157115459442
# running_loss_val:  0.3132617771625519
# validating: epoch:  40  loss:  0.3132617771625519
# The current loss: 0.3132617771625519
# the_last_loss: 0.3190157115459442
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  41  loss:  49.74255985021591 -- aux loss:  6.2134518921375275
# training: epoch:  42  loss:  49.71590656042099 -- aux loss:  6.294304341077805
# training: epoch:  43  loss:  49.73236846923828 -- aux loss:  6.201494783163071
# training: epoch:  44  loss:  49.703787714242935 -- aux loss:  6.241465210914612
# training: epoch:  45  loss:  49.62230658531189 -- aux loss:  6.225374400615692
# training: epoch:  46  loss:  49.62070447206497 -- aux loss:  6.13783672451973
# training: epoch:  47  loss:  49.67659777402878 -- aux loss:  6.351725280284882
# training: epoch:  48  loss:  49.644654512405396 -- aux loss:  6.188671052455902
# training: epoch:  49  loss:  49.66125774383545 -- aux loss:  6.116257578134537
# training: epoch:  50  loss:  49.698574244976044 -- aux loss:  6.048028826713562
# the_last_loss:  0.3132617771625519
# running_loss_val:  0.31326165795326233
# validating: epoch:  50  loss:  0.31326165795326233
# The current loss: 0.31326165795326233
# the_last_loss: 0.3132617771625519
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  51  loss:  49.62938115000725 -- aux loss:  6.01874378323555
# training: epoch:  52  loss:  49.65025869011879 -- aux loss:  6.086146116256714
# training: epoch:  53  loss:  49.61738854646683 -- aux loss:  6.018682956695557
# training: epoch:  54  loss:  49.688921600580215 -- aux loss:  6.147148907184601
# training: epoch:  55  loss:  49.61671423912048 -- aux loss:  6.098719477653503
# training: epoch:  56  loss:  49.6020302772522 -- aux loss:  6.074906796216965
# training: epoch:  57  loss:  49.645610362291336 -- aux loss:  6.045376479625702
# training: epoch:  58  loss:  49.61485329270363 -- aux loss:  6.099497854709625
# training: epoch:  59  loss:  49.636584639549255 -- aux loss:  6.1807727217674255
# training: epoch:  60  loss:  49.54205709695816 -- aux loss:  6.009369373321533
# the_last_loss:  0.31326165795326233
# running_loss_val:  0.31327587366104126
# validating: epoch:  60  loss:  0.31327587366104126
# The current loss: 0.31327587366104126
# the_last_loss: 0.31326165795326233
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  61  loss:  49.573724806308746 -- aux loss:  6.005698472261429
# training: epoch:  62  loss:  49.52184262871742 -- aux loss:  6.023035615682602
# training: epoch:  63  loss:  49.602358639240265 -- aux loss:  6.338167190551758
# training: epoch:  64  loss:  49.714695036411285 -- aux loss:  6.011906743049622
# training: epoch:  65  loss:  49.60250103473663 -- aux loss:  6.045564770698547
# training: epoch:  66  loss:  49.60840851068497 -- aux loss:  5.992126286029816
# training: epoch:  67  loss:  49.56887164711952 -- aux loss:  6.006061494350433
# training: epoch:  68  loss:  49.52078339457512 -- aux loss:  6.081447571516037
# training: epoch:  69  loss:  49.566073060035706 -- aux loss:  6.053780943155289
# training: epoch:  70  loss:  49.61467236280441 -- aux loss:  6.122842252254486
# the_last_loss:  0.31327587366104126
# running_loss_val:  0.316316694021225
# validating: epoch:  70  loss:  0.316316694021225
# The current loss: 0.316316694021225
# the_last_loss: 0.31327587366104126
# trigger times: 2
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  71  loss:  49.53937268257141 -- aux loss:  6.482481956481934
# training: epoch:  72  loss:  49.553975999355316 -- aux loss:  6.139009863138199
# training: epoch:  73  loss:  49.573681741952896 -- aux loss:  6.170389890670776
# training: epoch:  74  loss:  49.52877193689346 -- aux loss:  6.024656981229782
# training: epoch:  75  loss:  49.554138243198395 -- aux loss:  6.098649352788925
# training: epoch:  76  loss:  49.569056659936905 -- aux loss:  6.032237201929092
# training: epoch:  77  loss:  49.504866540431976 -- aux loss:  6.005311906337738
# training: epoch:  78  loss:  49.547841578722 -- aux loss:  6.080565631389618
# training: epoch:  79  loss:  49.577638387680054 -- aux loss:  6.2655501663684845
# training: epoch:  80  loss:  49.534709841012955 -- aux loss:  6.029156267642975
# the_last_loss:  0.316316694021225
# running_loss_val:  0.3132629692554474
# validating: epoch:  80  loss:  0.3132629692554474
# The current loss: 0.3132629692554474
# the_last_loss: 0.316316694021225
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  81  loss:  49.52465736865997 -- aux loss:  6.044514775276184
# training: epoch:  82  loss:  49.52998095750809 -- aux loss:  6.018619775772095
# training: epoch:  83  loss:  49.51838156580925 -- aux loss:  6.055571347475052
# training: epoch:  84  loss:  49.48443868756294 -- aux loss:  6.122158885002136
# training: epoch:  85  loss:  49.54468530416489 -- aux loss:  6.0816991329193115
# training: epoch:  86  loss:  49.501660227775574 -- aux loss:  6.036766558885574
# training: epoch:  87  loss:  49.504972726106644 -- aux loss:  6.054232060909271
# training: epoch:  88  loss:  49.48386499285698 -- aux loss:  5.973493009805679
# training: epoch:  89  loss:  49.45946231484413 -- aux loss:  6.014258652925491
# training: epoch:  90  loss:  49.46916085481644 -- aux loss:  6.121018975973129
# the_last_loss:  0.3132629692554474
# running_loss_val:  0.3205708861351013
# validating: epoch:  90  loss:  0.3205708861351013
# The current loss: 0.3205708861351013
# the_last_loss: 0.3132629692554474
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  91  loss:  49.56458979845047 -- aux loss:  6.056734472513199
# training: epoch:  92  loss:  49.47038012742996 -- aux loss:  6.01488384604454
# training: epoch:  93  loss:  49.49527767300606 -- aux loss:  6.030674487352371
# training: epoch:  94  loss:  49.46495592594147 -- aux loss:  6.017689347267151
# training: epoch:  95  loss:  49.50561735033989 -- aux loss:  6.023399651050568
# training: epoch:  96  loss:  49.45334035158157 -- aux loss:  5.9834263920784
# training: epoch:  97  loss:  49.47990646958351 -- aux loss:  5.9709808230400085
# training: epoch:  98  loss:  49.46082469820976 -- aux loss:  5.998285353183746
# training: epoch:  99  loss:  49.47008812427521 -- aux loss:  5.978141278028488
# training: epoch:  100  loss:  49.50646534562111 -- aux loss:  5.982911586761475
# the_last_loss:  0.3205708861351013
# running_loss_val:  0.31326156854629517
# validating: epoch:  100  loss:  0.31326156854629517
# The current loss: 0.31326156854629517
# the_last_loss: 0.3205708861351013
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  101  loss:  49.526292622089386 -- aux loss:  5.979842841625214
# training: epoch:  102  loss:  49.51271849870682 -- aux loss:  5.974700629711151
# training: epoch:  103  loss:  49.477243423461914 -- aux loss:  5.982499063014984
# training: epoch:  104  loss:  49.54998326301575 -- aux loss:  5.96028396487236
# training: epoch:  105  loss:  49.441543221473694 -- aux loss:  6.009121000766754
# training: epoch:  106  loss:  49.431680262088776 -- aux loss:  5.979194939136505
# training: epoch:  107  loss:  49.444369316101074 -- aux loss:  5.99867370724678
# training: epoch:  108  loss:  49.487358778715134 -- aux loss:  6.021751880645752
# training: epoch:  109  loss:  49.44052669405937 -- aux loss:  6.0826490223407745
# training: epoch:  110  loss:  49.44670107960701 -- aux loss:  5.95803689956665
# the_last_loss:  0.31326156854629517
# running_loss_val:  0.3132616877555847
# validating: epoch:  110  loss:  0.3132616877555847
# The current loss: 0.3132616877555847
# the_last_loss: 0.31326156854629517
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  111  loss:  49.468073189258575 -- aux loss:  5.974390596151352
# training: epoch:  112  loss:  49.48262122273445 -- aux loss:  5.980513572692871
# training: epoch:  113  loss:  49.48628208041191 -- aux loss:  6.005861610174179
# training: epoch:  114  loss:  49.424994856119156 -- aux loss:  5.985500365495682
# training: epoch:  115  loss:  49.41547229886055 -- aux loss:  5.967586070299149
# training: epoch:  116  loss:  49.4585979282856 -- aux loss:  6.082140415906906
# training: epoch:  117  loss:  49.47115954756737 -- aux loss:  6.030094355344772
# training: epoch:  118  loss:  49.418323427438736 -- aux loss:  5.995329707860947
# training: epoch:  119  loss:  49.41247522830963 -- aux loss:  6.000833660364151
# training: epoch:  120  loss:  49.507448971271515 -- aux loss:  6.003359019756317
# the_last_loss:  0.3132616877555847
# running_loss_val:  0.32031887769699097
# validating: epoch:  120  loss:  0.32031887769699097
# The current loss: 0.32031887769699097
# the_last_loss: 0.3132616877555847
# trigger times: 2
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  121  loss:  49.440844506025314 -- aux loss:  5.9680638909339905
# training: epoch:  122  loss:  49.44512149691582 -- aux loss:  5.989994138479233
# training: epoch:  123  loss:  49.42827180027962 -- aux loss:  5.971127092838287
# training: epoch:  124  loss:  49.414305210113525 -- aux loss:  5.9720121920108795
# training: epoch:  125  loss:  49.40315881371498 -- aux loss:  6.007328808307648
# training: epoch:  126  loss:  49.45550438761711 -- aux loss:  6.0369861125946045
# training: epoch:  127  loss:  49.50328657031059 -- aux loss:  6.057321459054947
# training: epoch:  128  loss:  49.49127870798111 -- aux loss:  6.152757048606873
# training: epoch:  129  loss:  49.41654768586159 -- aux loss:  6.00807848572731
# training: epoch:  130  loss:  49.401606380939484 -- aux loss:  6.024654388427734
# the_last_loss:  0.32031887769699097
# running_loss_val:  0.3248515725135803
# validating: epoch:  130  loss:  0.3248515725135803
# The current loss: 0.3248515725135803
# the_last_loss: 0.32031887769699097
# trigger times: 3
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  131  loss:  49.470037281513214 -- aux loss:  5.992033421993256
# training: epoch:  132  loss:  49.451339691877365 -- aux loss:  5.966371774673462
# training: epoch:  133  loss:  49.41261798143387 -- aux loss:  5.964446276426315
# training: epoch:  134  loss:  49.44470453262329 -- aux loss:  5.972089618444443
# training: epoch:  135  loss:  49.43003413081169 -- aux loss:  5.980782330036163
# training: epoch:  136  loss:  49.48347193002701 -- aux loss:  6.069254845380783
# training: epoch:  137  loss:  49.47209957242012 -- aux loss:  5.999583512544632
# training: epoch:  138  loss:  49.441024869680405 -- aux loss:  5.979028433561325
# training: epoch:  139  loss:  49.49116042256355 -- aux loss:  5.993742138147354
# training: epoch:  140  loss:  49.416501104831696 -- aux loss:  5.967133313417435
# the_last_loss:  0.3248515725135803
# running_loss_val:  0.3132629096508026
# validating: epoch:  140  loss:  0.3132629096508026
# The current loss: 0.3132629096508026
# the_last_loss: 0.3248515725135803
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  141  loss:  49.41765132546425 -- aux loss:  5.961620271205902
# training: epoch:  142  loss:  49.40503212809563 -- aux loss:  5.974035561084747
# training: epoch:  143  loss:  49.43701374530792 -- aux loss:  5.972003102302551
# training: epoch:  144  loss:  49.40490213036537 -- aux loss:  5.96646448969841
# training: epoch:  145  loss:  49.39195445179939 -- aux loss:  5.979930073022842
# training: epoch:  146  loss:  49.415300607681274 -- aux loss:  5.964791864156723
# training: epoch:  147  loss:  49.405357748270035 -- aux loss:  5.969833493232727
# training: epoch:  148  loss:  49.386316150426865 -- aux loss:  5.962712049484253
# training: epoch:  149  loss:  49.39480409026146 -- aux loss:  5.972730189561844
# training: epoch:  150  loss:  49.42901968955994 -- aux loss:  5.98373019695282
# the_last_loss:  0.3132629096508026
# running_loss_val:  0.32287517189979553
# validating: epoch:  150  loss:  0.32287517189979553
# The current loss: 0.32287517189979553
# the_last_loss: 0.3132629096508026
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  151  loss:  49.457575261592865 -- aux loss:  5.994493842124939
# training: epoch:  152  loss:  49.45306006073952 -- aux loss:  5.998278439044952
# training: epoch:  153  loss:  49.406379610300064 -- aux loss:  5.98135033249855
# training: epoch:  154  loss:  49.3938490152359 -- aux loss:  5.984570860862732
# training: epoch:  155  loss:  49.455757439136505 -- aux loss:  5.98108372092247
# training: epoch:  156  loss:  49.410727858543396 -- aux loss:  6.007474213838577
# training: epoch:  157  loss:  49.40216106176376 -- aux loss:  5.97679740190506
# training: epoch:  158  loss:  49.43950918316841 -- aux loss:  6.010497987270355
# training: epoch:  159  loss:  49.461282670497894 -- aux loss:  6.007649213075638
# training: epoch:  160  loss:  49.42283409833908 -- aux loss:  5.959895521402359
# the_last_loss:  0.32287517189979553
# running_loss_val:  0.31326159834861755
# validating: epoch:  160  loss:  0.31326159834861755
# The current loss: 0.31326159834861755
# the_last_loss: 0.32287517189979553
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  161  loss:  49.41668200492859 -- aux loss:  5.954138606786728
# training: epoch:  162  loss:  49.41970932483673 -- aux loss:  5.992649435997009
# training: epoch:  163  loss:  49.40137356519699 -- aux loss:  5.992041170597076
# training: epoch:  164  loss:  49.400917172431946 -- aux loss:  5.983315408229828
# training: epoch:  165  loss:  49.383097022771835 -- aux loss:  6.013211369514465
# training: epoch:  166  loss:  49.3831829726696 -- aux loss:  6.024447023868561
# training: epoch:  167  loss:  49.38755890727043 -- aux loss:  5.998951643705368
# training: epoch:  168  loss:  49.36760854721069 -- aux loss:  5.980520874261856
# training: epoch:  169  loss:  49.4058652818203 -- aux loss:  6.051002025604248
# training: epoch:  170  loss:  49.42140471935272 -- aux loss:  6.001699835062027
# the_last_loss:  0.31326159834861755
# running_loss_val:  0.31326428055763245
# validating: epoch:  170  loss:  0.31326428055763245
# The current loss: 0.31326428055763245
# the_last_loss: 0.31326159834861755
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  171  loss:  49.41183117032051 -- aux loss:  5.958513706922531
# training: epoch:  172  loss:  49.39681780338287 -- aux loss:  5.966691583395004
# training: epoch:  173  loss:  49.40694510936737 -- aux loss:  5.975875437259674
# training: epoch:  174  loss:  49.40148416161537 -- aux loss:  5.981516808271408
# training: epoch:  175  loss:  49.394570767879486 -- aux loss:  5.998646646738052
# training: epoch:  176  loss:  49.40166461467743 -- aux loss:  5.990202099084854
# training: epoch:  177  loss:  49.438526183366776 -- aux loss:  6.025778949260712
# training: epoch:  178  loss:  49.441899836063385 -- aux loss:  6.046022951602936
# training: epoch:  179  loss:  49.41219764947891 -- aux loss:  5.985645622014999
# training: epoch:  180  loss:  49.385192573070526 -- aux loss:  5.968028962612152
# the_last_loss:  0.31326428055763245
# running_loss_val:  0.3189770579338074
# validating: epoch:  180  loss:  0.3189770579338074
# The current loss: 0.3189770579338074
# the_last_loss: 0.31326428055763245
# trigger times: 2
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  181  loss:  49.404122084379196 -- aux loss:  5.993630617856979
# training: epoch:  182  loss:  49.407642275094986 -- aux loss:  5.974053710699081
# training: epoch:  183  loss:  49.38175210356712 -- aux loss:  5.965049654245377
# training: epoch:  184  loss:  49.40713983774185 -- aux loss:  5.962197631597519
# training: epoch:  185  loss:  49.383521020412445 -- aux loss:  5.9606190621852875
# training: epoch:  186  loss:  49.37824881076813 -- aux loss:  5.967239111661911
# training: epoch:  187  loss:  49.39798575639725 -- aux loss:  5.965222358703613
# training: epoch:  188  loss:  49.370930671691895 -- aux loss:  5.959282875061035
# training: epoch:  189  loss:  49.36265167593956 -- aux loss:  5.9839403331279755
# training: epoch:  190  loss:  49.364478290081024 -- aux loss:  5.968542695045471
# the_last_loss:  0.3189770579338074
# running_loss_val:  0.31326156854629517
# validating: epoch:  190  loss:  0.31326156854629517
# The current loss: 0.31326156854629517
# the_last_loss: 0.3189770579338074
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  191  loss:  49.35282164812088 -- aux loss:  5.971351474523544
# training: epoch:  192  loss:  49.399432361125946 -- aux loss:  5.960223764181137
# training: epoch:  193  loss:  49.39241415262222 -- aux loss:  5.953550100326538
# training: epoch:  194  loss:  49.428770035505295 -- aux loss:  5.9832777082920074
# training: epoch:  195  loss:  49.4145388007164 -- aux loss:  5.979681700468063
# training: epoch:  196  loss:  49.403220534324646 -- aux loss:  6.004786044359207
# training: epoch:  197  loss:  49.42104774713516 -- aux loss:  6.088604211807251
# training: epoch:  198  loss:  49.420852333307266 -- aux loss:  5.965890526771545
# training: epoch:  199  loss:  49.46258503198624 -- aux loss:  5.982149690389633
# training: epoch:  200  loss:  49.40911427140236 -- aux loss:  5.972741961479187
# the_last_loss:  0.31326156854629517
# running_loss_val:  0.3154035806655884
# validating: epoch:  200  loss:  0.3154035806655884
# The current loss: 0.3154035806655884
# the_last_loss: 0.31326156854629517
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  201  loss:  49.4081175327301 -- aux loss:  5.966176688671112
# training: epoch:  202  loss:  49.402949780225754 -- aux loss:  5.957367241382599
# training: epoch:  203  loss:  49.41311785578728 -- aux loss:  5.960196644067764
# training: epoch:  204  loss:  49.391192615032196 -- aux loss:  5.979577541351318
# training: epoch:  205  loss:  49.39510136842728 -- aux loss:  5.9772466123104095
# training: epoch:  206  loss:  49.38636523485184 -- aux loss:  5.976564675569534
# training: epoch:  207  loss:  49.36718708276749 -- aux loss:  5.981829583644867
# training: epoch:  208  loss:  49.3455865085125 -- aux loss:  5.974097311496735
# training: epoch:  209  loss:  49.34674593806267 -- aux loss:  6.012492805719376
# training: epoch:  210  loss:  49.36594992876053 -- aux loss:  5.9658364951610565
# the_last_loss:  0.3154035806655884
# running_loss_val:  0.3132631182670593
# validating: epoch:  210  loss:  0.3132631182670593
# The current loss: 0.3132631182670593
# the_last_loss: 0.3154035806655884
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  211  loss:  49.392545372247696 -- aux loss:  5.991881966590881
# training: epoch:  212  loss:  49.42202550172806 -- aux loss:  5.997047513723373
# training: epoch:  213  loss:  49.376399993896484 -- aux loss:  5.975109249353409
# training: epoch:  214  loss:  49.38859301805496 -- aux loss:  5.976573556661606
# training: epoch:  215  loss:  49.38509523868561 -- aux loss:  5.984308063983917
# training: epoch:  216  loss:  49.41556403040886 -- aux loss:  5.996338754892349
# training: epoch:  217  loss:  49.39411625266075 -- aux loss:  5.968330770730972
# training: epoch:  218  loss:  49.37259989976883 -- aux loss:  5.961834639310837
# training: epoch:  219  loss:  49.37053003907204 -- aux loss:  5.990303844213486
# training: epoch:  220  loss:  49.38707700371742 -- aux loss:  5.964354783296585
# the_last_loss:  0.3132631182670593
# running_loss_val:  0.31326159834861755
# validating: epoch:  220  loss:  0.31326159834861755
# The current loss: 0.31326159834861755
# the_last_loss: 0.3132631182670593
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  221  loss:  49.363033682107925 -- aux loss:  6.000331699848175
# training: epoch:  222  loss:  49.373105585575104 -- aux loss:  6.045512467622757
# training: epoch:  223  loss:  49.38320404291153 -- aux loss:  5.983722656965256
# training: epoch:  224  loss:  49.412521094083786 -- aux loss:  5.978226542472839
# training: epoch:  225  loss:  49.37388852238655 -- aux loss:  5.981478273868561
# training: epoch:  226  loss:  49.368519216775894 -- aux loss:  5.962873309850693
# training: epoch:  227  loss:  49.37610065937042 -- aux loss:  5.956590235233307
# training: epoch:  228  loss:  49.36154702305794 -- aux loss:  5.959278553724289
# training: epoch:  229  loss:  49.35501581430435 -- aux loss:  5.959155857563019
# training: epoch:  230  loss:  49.38674482703209 -- aux loss:  5.98845049738884
# the_last_loss:  0.31326159834861755
# running_loss_val:  0.3151140511035919
# validating: epoch:  230  loss:  0.3151140511035919
# The current loss: 0.3151140511035919
# the_last_loss: 0.31326159834861755
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  231  loss:  49.44182375073433 -- aux loss:  5.959273725748062
# training: epoch:  232  loss:  49.3752201795578 -- aux loss:  5.9581078588962555
# training: epoch:  233  loss:  49.37306967377663 -- aux loss:  5.95588544011116
# training: epoch:  234  loss:  49.37945485115051 -- aux loss:  5.964215666055679
# training: epoch:  235  loss:  49.348321586847305 -- aux loss:  5.955915063619614
# training: epoch:  236  loss:  49.35392156243324 -- aux loss:  5.9588989317417145
# training: epoch:  237  loss:  49.400311559438705 -- aux loss:  5.952314585447311
# training: epoch:  238  loss:  49.37407246232033 -- aux loss:  5.959041982889175
# training: epoch:  239  loss:  49.37915527820587 -- aux loss:  5.952067673206329
# training: epoch:  240  loss:  49.37553009390831 -- aux loss:  5.981271475553513
# the_last_loss:  0.3151140511035919
# running_loss_val:  0.31491175293922424
# validating: epoch:  240  loss:  0.31491175293922424
# The current loss: 0.31491175293922424
# the_last_loss: 0.3151140511035919
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  241  loss:  49.37159463763237 -- aux loss:  5.9537979662418365
# training: epoch:  242  loss:  49.38072019815445 -- aux loss:  5.953475385904312
# training: epoch:  243  loss:  49.35128089785576 -- aux loss:  5.9568080604076385
# training: epoch:  244  loss:  49.362626016139984 -- aux loss:  5.960035085678101
# training: epoch:  245  loss:  49.34527242183685 -- aux loss:  5.954504281282425
# training: epoch:  246  loss:  49.34345152974129 -- aux loss:  5.952438950538635
# training: epoch:  247  loss:  49.39898207783699 -- aux loss:  5.955173194408417
# training: epoch:  248  loss:  49.3934280872345 -- aux loss:  5.963851660490036
# training: epoch:  249  loss:  49.35996696352959 -- aux loss:  5.960475653409958
# training: epoch:  250  loss:  49.362873047590256 -- aux loss:  5.955938547849655
# the_last_loss:  0.31491175293922424
# running_loss_val:  0.31326156854629517
# validating: epoch:  250  loss:  0.31326156854629517
# The current loss: 0.31326156854629517
# the_last_loss: 0.31491175293922424
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  251  loss:  49.37323370575905 -- aux loss:  5.962179809808731
# training: epoch:  252  loss:  49.36249700188637 -- aux loss:  5.960041135549545
# training: epoch:  253  loss:  49.37231621146202 -- aux loss:  5.965785592794418
# training: epoch:  254  loss:  49.391844153404236 -- aux loss:  5.967434287071228
# training: epoch:  255  loss:  49.3941895365715 -- aux loss:  5.951991409063339
# training: epoch:  256  loss:  49.40620708465576 -- aux loss:  5.960326105356216
# training: epoch:  257  loss:  49.38438865542412 -- aux loss:  5.970461010932922
# training: epoch:  258  loss:  49.36479365825653 -- aux loss:  5.954634755849838
# training: epoch:  259  loss:  49.35026654601097 -- aux loss:  5.95538404583931
# training: epoch:  260  loss:  49.417699724435806 -- aux loss:  5.952014684677124
# the_last_loss:  0.31326156854629517
# running_loss_val:  0.31326156854629517
# validating: epoch:  260  loss:  0.31326156854629517
# The current loss: 0.31326156854629517
# the_last_loss: 0.31326156854629517
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  261  loss:  49.38527259230614 -- aux loss:  5.960322231054306
# training: epoch:  262  loss:  49.44717016816139 -- aux loss:  5.952976942062378
# training: epoch:  263  loss:  49.34985026717186 -- aux loss:  5.952561676502228
# training: epoch:  264  loss:  49.340575367212296 -- aux loss:  5.957781374454498
# training: epoch:  265  loss:  49.35280713438988 -- aux loss:  5.951977431774139
# training: epoch:  266  loss:  49.347141325473785 -- aux loss:  5.957368731498718
# training: epoch:  267  loss:  49.348956912755966 -- aux loss:  5.965020418167114
# training: epoch:  268  loss:  49.374902456998825 -- aux loss:  5.956170737743378
# training: epoch:  269  loss:  49.39376375079155 -- aux loss:  5.956222712993622
# training: epoch:  270  loss:  49.364979326725006 -- aux loss:  5.958205729722977
# the_last_loss:  0.31326156854629517
# running_loss_val:  0.31326156854629517
# validating: epoch:  270  loss:  0.31326156854629517
# The current loss: 0.31326156854629517
# the_last_loss: 0.31326156854629517
# trigger times: 2
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  271  loss:  49.42467272281647 -- aux loss:  5.955941587686539
# training: epoch:  272  loss:  49.3692272901535 -- aux loss:  5.958279073238373
# training: epoch:  273  loss:  49.367692679166794 -- aux loss:  5.95547091960907
# training: epoch:  274  loss:  49.34858277440071 -- aux loss:  5.958400934934616
# training: epoch:  275  loss:  49.34798467159271 -- aux loss:  5.955173939466476
# training: epoch:  276  loss:  49.355939239263535 -- aux loss:  5.951988399028778
# training: epoch:  277  loss:  49.34405338764191 -- aux loss:  5.953622668981552
# training: epoch:  278  loss:  49.34549984335899 -- aux loss:  5.952009588479996
# training: epoch:  279  loss:  49.34612864255905 -- aux loss:  5.959122389554977
# training: epoch:  280  loss:  49.38429170846939 -- aux loss:  5.972466439008713
# the_last_loss:  0.31326156854629517
# running_loss_val:  0.3187953233718872
# validating: epoch:  280  loss:  0.3187953233718872
# The current loss: 0.3187953233718872
# the_last_loss: 0.31326156854629517
# trigger times: 3
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  281  loss:  49.3693742454052 -- aux loss:  5.962091505527496
# training: epoch:  282  loss:  49.37892186641693 -- aux loss:  5.956638336181641
# training: epoch:  283  loss:  49.364433497190475 -- aux loss:  5.953854262828827
# training: epoch:  284  loss:  49.40524506568909 -- aux loss:  5.955234229564667
# training: epoch:  285  loss:  49.35349681973457 -- aux loss:  5.952358961105347
# training: epoch:  286  loss:  49.37227153778076 -- aux loss:  5.962859779596329
# training: epoch:  287  loss:  49.360286474227905 -- aux loss:  5.959428369998932
# training: epoch:  288  loss:  49.37032833695412 -- aux loss:  5.962123423814774
# training: epoch:  289  loss:  49.354055762290955 -- aux loss:  5.958625644445419
# training: epoch:  290  loss:  49.36188694834709 -- aux loss:  5.957113683223724
# the_last_loss:  0.3187953233718872
# running_loss_val:  0.31326156854629517
# validating: epoch:  290  loss:  0.31326156854629517
# The current loss: 0.31326156854629517
# the_last_loss: 0.3187953233718872
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  291  loss:  49.368674486875534 -- aux loss:  5.961703330278397
# training: epoch:  292  loss:  49.36004754900932 -- aux loss:  5.969579309225082
# training: epoch:  293  loss:  49.363331347703934 -- aux loss:  5.967806041240692
# training: epoch:  294  loss:  49.351730674505234 -- aux loss:  5.964199930429459
# training: epoch:  295  loss:  49.387325435876846 -- aux loss:  5.973519027233124
# training: epoch:  296  loss:  49.35729140043259 -- aux loss:  5.9578151404857635
# training: epoch:  297  loss:  49.34701955318451 -- aux loss:  5.954821884632111
# training: epoch:  298  loss:  49.355659663677216 -- aux loss:  5.960766762495041
# training: epoch:  299  loss:  49.411261320114136 -- aux loss:  5.961064517498016
# training: epoch:  300  loss:  49.37604737281799 -- aux loss:  5.9641255140304565
# the_last_loss:  0.31326156854629517
# running_loss_val:  0.31328824162483215
# validating: epoch:  300  loss:  0.31328824162483215
# The current loss: 0.31328824162483215
# the_last_loss: 0.31326156854629517
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  301  loss:  49.36835381388664 -- aux loss:  5.958768218755722
# training: epoch:  302  loss:  49.35503324866295 -- aux loss:  5.970088750123978
# training: epoch:  303  loss:  49.371925950050354 -- aux loss:  5.953188478946686
# training: epoch:  304  loss:  49.3555743098259 -- aux loss:  5.966563791036606
# training: epoch:  305  loss:  49.34758576750755 -- aux loss:  5.9692302942276
# training: epoch:  306  loss:  49.37807434797287 -- aux loss:  5.956903785467148
# training: epoch:  307  loss:  49.38340872526169 -- aux loss:  5.9706874787807465
# training: epoch:  308  loss:  49.37387213110924 -- aux loss:  5.962689191102982
# training: epoch:  309  loss:  49.36458072066307 -- aux loss:  5.960046410560608
# training: epoch:  310  loss:  49.36090052127838 -- aux loss:  5.961546957492828
# the_last_loss:  0.31328824162483215
# running_loss_val:  0.31544190645217896
# validating: epoch:  310  loss:  0.31544190645217896
# The current loss: 0.31544190645217896
# the_last_loss: 0.31328824162483215
# trigger times: 2
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  311  loss:  49.354667603969574 -- aux loss:  5.95842307806015
# training: epoch:  312  loss:  49.382364213466644 -- aux loss:  5.953944981098175
# training: epoch:  313  loss:  49.35262879729271 -- aux loss:  5.952681928873062
# training: epoch:  314  loss:  49.35399267077446 -- aux loss:  5.953366339206696
# training: epoch:  315  loss:  49.351519137620926 -- aux loss:  5.956141650676727
# training: epoch:  316  loss:  49.34441331028938 -- aux loss:  5.962569624185562
# training: epoch:  317  loss:  49.34307789802551 -- aux loss:  5.959778368473053
# training: epoch:  318  loss:  49.405471831560135 -- aux loss:  5.970215380191803
# training: epoch:  319  loss:  49.37701779603958 -- aux loss:  5.968860000371933
# training: epoch:  320  loss:  49.362920224666595 -- aux loss:  5.9707542061805725
# the_last_loss:  0.31544190645217896
# running_loss_val:  0.31510406732559204
# validating: epoch:  320  loss:  0.31510406732559204
# The current loss: 0.31510406732559204
# the_last_loss: 0.31544190645217896
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  321  loss:  49.34990480542183 -- aux loss:  5.958113938570023
# training: epoch:  322  loss:  49.34761920571327 -- aux loss:  5.95287299156189
# training: epoch:  323  loss:  49.33170211315155 -- aux loss:  5.956806570291519
# training: epoch:  324  loss:  49.34532269835472 -- aux loss:  5.95479342341423
# training: epoch:  325  loss:  49.343230336904526 -- aux loss:  5.953174561262131
# training: epoch:  326  loss:  49.331317991018295 -- aux loss:  5.953432261943817
# training: epoch:  327  loss:  49.347866743803024 -- aux loss:  5.955861955881119
# training: epoch:  328  loss:  49.40086716413498 -- aux loss:  5.960674852132797
# training: epoch:  329  loss:  49.38353005051613 -- aux loss:  5.957980155944824
# training: epoch:  330  loss:  49.370959013700485 -- aux loss:  5.956033706665039
# the_last_loss:  0.31510406732559204
# running_loss_val:  0.31326165795326233
# validating: epoch:  330  loss:  0.31326165795326233
# The current loss: 0.31326165795326233
# the_last_loss: 0.31510406732559204
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  331  loss:  49.4032176733017 -- aux loss:  5.955879122018814
# training: epoch:  332  loss:  49.377222299575806 -- aux loss:  5.9592907428741455
# training: epoch:  333  loss:  49.372119426727295 -- aux loss:  5.9538184106349945
# training: epoch:  334  loss:  49.396732062101364 -- aux loss:  5.965826630592346
# training: epoch:  335  loss:  49.36271473765373 -- aux loss:  5.955348163843155
# training: epoch:  336  loss:  49.339031398296356 -- aux loss:  5.957312196493149
# training: epoch:  337  loss:  49.34218928217888 -- aux loss:  5.957138150930405
# training: epoch:  338  loss:  49.35946035385132 -- aux loss:  5.971756219863892
# training: epoch:  339  loss:  49.4894657433033 -- aux loss:  5.958901435136795
# training: epoch:  340  loss:  49.364776849746704 -- aux loss:  5.9548333287239075
# the_last_loss:  0.31326165795326233
# running_loss_val:  0.31326159834861755
# validating: epoch:  340  loss:  0.31326159834861755
# The current loss: 0.31326159834861755
# the_last_loss: 0.31326165795326233
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  341  loss:  49.36374852061272 -- aux loss:  5.9669269323349
# training: epoch:  342  loss:  49.35061353445053 -- aux loss:  5.953504681587219
# training: epoch:  343  loss:  49.36961480975151 -- aux loss:  5.953222900629044
# training: epoch:  344  loss:  49.3500454723835 -- aux loss:  5.9540418684482574
# training: epoch:  345  loss:  49.33324036002159 -- aux loss:  5.953664153814316
# training: epoch:  346  loss:  49.351963609457016 -- aux loss:  5.953937113285065
# training: epoch:  347  loss:  49.34979245066643 -- aux loss:  5.965618222951889
# training: epoch:  348  loss:  49.33476880192757 -- aux loss:  5.954588383436203
# training: epoch:  349  loss:  49.34516677260399 -- aux loss:  5.956436634063721
# training: epoch:  350  loss:  49.359414011240005 -- aux loss:  5.954656898975372
# the_last_loss:  0.31326159834861755
# running_loss_val:  0.3132616877555847
# validating: epoch:  350  loss:  0.3132616877555847
# The current loss: 0.3132616877555847
# the_last_loss: 0.31326159834861755
# trigger times: 1
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# sum mask2 - L3:  tensor(151, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1201, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2447, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(49, device='cuda:0')
# training: epoch:  351  loss:  49.36053776741028 -- aux loss:  5.959378242492676
# training: epoch:  352  loss:  49.36394000053406 -- aux loss:  5.958152741193771
# training: epoch:  353  loss:  49.39831566810608 -- aux loss:  5.9541648626327515
# training: epoch:  354  loss:  49.3757629096508 -- aux loss:  5.955089747905731
# training: epoch:  355  loss:  49.364368587732315 -- aux loss:  5.955882489681244
# training: epoch:  356  loss:  49.34182748198509 -- aux loss:  5.955347329378128
# training: epoch:  357  loss:  49.34207275509834 -- aux loss:  5.952062517404556
# training: epoch:  358  loss:  49.352292358875275 -- aux loss:  5.956798672676086
# training: epoch:  359  loss:  49.39105612039566 -- aux loss:  5.954893350601196
# training: epoch:  360  loss:  49.362488597631454 -- aux loss:  5.952244460582733
# the_last_loss:  0.3132616877555847
# running_loss_val:  0.31326156854629517
# validating: epoch:  360  loss:  0.31326156854629517
# The current loss: 0.31326156854629517
# the_last_loss: 0.3132616877555847
# trigger times: 0
# sum mask2 - L1:  tensor(4799, device='cuda:0')
# sum mask2 - L2:  tensor(7553, device='cuda:0')
# ...
# running_loss_val:  0.9327890276908875
# validating: epoch:  1430  loss:  0.9327890276908875
# The current loss: 0.9327890276908875
# the_last_loss: 0.9381645321846008
# trigger times: 0
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# training: epoch:  1431  loss:  98.62114840745926 -- aux loss:  0
# training: epoch:  1432  loss:  98.61662811040878 -- aux loss:  0
# training: epoch:  1433  loss:  98.61710458993912 -- aux loss:  0
# training: epoch:  1434  loss:  98.61415332555771 -- aux loss:  0
# training: epoch:  1435  loss:  98.6145492196083 -- aux loss:  0
# training: epoch:  1436  loss:  98.6190675497055 -- aux loss:  0
# training: epoch:  1437  loss:  98.621935069561 -- aux loss:  0
# training: epoch:  1438  loss:  98.61468136310577 -- aux loss:  0
# training: epoch:  1439  loss:  98.61430668830872 -- aux loss:  0
# training: epoch:  1440  loss:  98.63682043552399 -- aux loss:  0
# the_last_loss:  0.9327890276908875
# running_loss_val:  0.9113085269927979
# validating: epoch:  1440  loss:  0.9113085269927979
# The current loss: 0.9113085269927979
# the_last_loss: 0.9327890276908875
# trigger times: 0
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# training: epoch:  1441  loss:  98.64002418518066 -- aux loss:  0
# training: epoch:  1442  loss:  98.70148462057114 -- aux loss:  0
# training: epoch:  1443  loss:  98.63866478204727 -- aux loss:  0
# training: epoch:  1444  loss:  98.64932936429977 -- aux loss:  0
# training: epoch:  1445  loss:  98.62313294410706 -- aux loss:  0
# training: epoch:  1446  loss:  98.61443847417831 -- aux loss:  0
# training: epoch:  1447  loss:  98.61457222700119 -- aux loss:  0
# training: epoch:  1448  loss:  98.6141608953476 -- aux loss:  0
# training: epoch:  1449  loss:  98.61417818069458 -- aux loss:  0
# training: epoch:  1450  loss:  98.6141522526741 -- aux loss:  0
# the_last_loss:  0.9113085269927979
# running_loss_val:  0.9169352054595947
# validating: epoch:  1450  loss:  0.9169352054595947
# The current loss: 0.9169352054595947
# the_last_loss: 0.9113085269927979
# trigger times: 1
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# training: epoch:  1451  loss:  98.62186789512634 -- aux loss:  0
# training: epoch:  1452  loss:  98.62504154443741 -- aux loss:  0
# training: epoch:  1453  loss:  98.62052029371262 -- aux loss:  0
# training: epoch:  1454  loss:  98.61630326509476 -- aux loss:  0
# training: epoch:  1455  loss:  98.64847964048386 -- aux loss:  0
# training: epoch:  1456  loss:  98.63017982244492 -- aux loss:  0
# training: epoch:  1457  loss:  98.62936389446259 -- aux loss:  0
# training: epoch:  1458  loss:  98.61424821615219 -- aux loss:  0
# training: epoch:  1459  loss:  98.6144323348999 -- aux loss:  0
# training: epoch:  1460  loss:  98.61616319417953 -- aux loss:  0
# the_last_loss:  0.9169352054595947
# running_loss_val:  0.8958457112312317
# validating: epoch:  1460  loss:  0.8958457112312317
# The current loss: 0.8958457112312317
# the_last_loss: 0.9169352054595947
# trigger times: 0
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# training: epoch:  1461  loss:  98.64668464660645 -- aux loss:  0
# training: epoch:  1462  loss:  98.65948420763016 -- aux loss:  0
# training: epoch:  1463  loss:  98.65058034658432 -- aux loss:  0
# training: epoch:  1464  loss:  98.65324008464813 -- aux loss:  0
# training: epoch:  1465  loss:  98.6240862607956 -- aux loss:  0
# training: epoch:  1466  loss:  98.62245684862137 -- aux loss:  0
# training: epoch:  1467  loss:  98.6361466050148 -- aux loss:  0
# training: epoch:  1468  loss:  98.66305756568909 -- aux loss:  0
# training: epoch:  1469  loss:  98.64303863048553 -- aux loss:  0
# training: epoch:  1470  loss:  98.62021201848984 -- aux loss:  0
# the_last_loss:  0.8958457112312317
# running_loss_val:  0.8838398456573486
# validating: epoch:  1470  loss:  0.8838398456573486
# The current loss: 0.8838398456573486
# the_last_loss: 0.8958457112312317
# trigger times: 0
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# training: epoch:  1471  loss:  98.65351337194443 -- aux loss:  0
# training: epoch:  1472  loss:  98.6371568441391 -- aux loss:  0
# training: epoch:  1473  loss:  98.62222003936768 -- aux loss:  0
# training: epoch:  1474  loss:  98.63966369628906 -- aux loss:  0
# training: epoch:  1475  loss:  98.62825644016266 -- aux loss:  0
# training: epoch:  1476  loss:  98.6513522863388 -- aux loss:  0
# training: epoch:  1477  loss:  98.6181378364563 -- aux loss:  0
# training: epoch:  1478  loss:  98.61732369661331 -- aux loss:  0
# training: epoch:  1479  loss:  98.61420613527298 -- aux loss:  0
# training: epoch:  1480  loss:  98.63655269145966 -- aux loss:  0
# the_last_loss:  0.8838398456573486
# running_loss_val:  0.8554018139839172
# validating: epoch:  1480  loss:  0.8554018139839172
# The current loss: 0.8554018139839172
# the_last_loss: 0.8838398456573486
# trigger times: 0
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# training: epoch:  1481  loss:  98.65721380710602 -- aux loss:  0
# training: epoch:  1482  loss:  98.62242758274078 -- aux loss:  0
# training: epoch:  1483  loss:  98.63725262880325 -- aux loss:  0
# training: epoch:  1484  loss:  98.62658786773682 -- aux loss:  0
# training: epoch:  1485  loss:  98.61477869749069 -- aux loss:  0
# training: epoch:  1486  loss:  98.62344175577164 -- aux loss:  0
# training: epoch:  1487  loss:  98.63062942028046 -- aux loss:  0
# training: epoch:  1488  loss:  98.63383823633194 -- aux loss:  0
# training: epoch:  1489  loss:  98.61533534526825 -- aux loss:  0
# training: epoch:  1490  loss:  98.62789219617844 -- aux loss:  0
# the_last_loss:  0.8554018139839172
# running_loss_val:  0.8638293147087097
# validating: epoch:  1490  loss:  0.8638293147087097
# The current loss: 0.8638293147087097
# the_last_loss: 0.8554018139839172
# trigger times: 1
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# training: epoch:  1491  loss:  98.63021767139435 -- aux loss:  0
# training: epoch:  1492  loss:  98.61640685796738 -- aux loss:  0
# training: epoch:  1493  loss:  98.61465376615524 -- aux loss:  0
# training: epoch:  1494  loss:  98.61741542816162 -- aux loss:  0
# training: epoch:  1495  loss:  98.63914507627487 -- aux loss:  0
# training: epoch:  1496  loss:  98.63502299785614 -- aux loss:  0
# training: epoch:  1497  loss:  98.62946838140488 -- aux loss:  0
# training: epoch:  1498  loss:  98.62482976913452 -- aux loss:  0
# training: epoch:  1499  loss:  98.61719173192978 -- aux loss:  0
# training: epoch:  1500  loss:  98.61855846643448 -- aux loss:  0
# the_last_loss:  0.8638293147087097
# running_loss_val:  0.9075409173965454
# validating: epoch:  1500  loss:  0.9075409173965454
# The current loss: 0.9075409173965454
# the_last_loss: 0.8638293147087097
# trigger times: 2
# sum mask2 - L1:  tensor(4895, device='cuda:0')
# sum mask2 - L2:  tensor(7551, device='cuda:0')
# sum mask2 - L3:  tensor(141, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1105, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2449, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(59, device='cuda:0')
# recall
# tensor(0.9997)
# precision
# tensor(0.9989)
# f1_score
# tensor(0.9993)
# Accuracy of the network on test objects: 99 %
# 99.8853
# recall
# tensor(0.9987)
# precision
# tensor(0.0519)
# f1_score
# tensor(0.0986)
# Accuracy of the network on test objects: 5 %
# 5.1881075
# Freq1_harmonics_rel_phase_0
# Freq2_harmonics_rel_phase_0
# Freq3_harmonics_rel_phase_0
# ____get_tensor_function____
# shape tensor:  torch.Size([4765, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([1192, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([40000, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([50000, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([1192, 60])
# ____get_tensor_function____
# /home/franciscoperez/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# shape tensor:  torch.Size([353747, 60])
# ____get_tensor_function____
# shape tensor:  torch.Size([353747, 60])
# training: epoch:  1  loss:  108.63395220041275 -- aux loss:  0
# training: epoch:  2  loss:  101.61429715156555 -- aux loss:  0
# training: epoch:  3  loss:  101.37014842033386 -- aux loss:  0
# training: epoch:  4  loss:  101.24822676181793 -- aux loss:  0
# training: epoch:  5  loss:  100.8921103477478 -- aux loss:  0
# training: epoch:  6  loss:  100.84391170740128 -- aux loss:  0
# training: epoch:  7  loss:  100.96200269460678 -- aux loss:  0
# training: epoch:  8  loss:  100.6384459733963 -- aux loss:  0
# training: epoch:  9  loss:  100.42444759607315 -- aux loss:  0
# training: epoch:  10  loss:  100.54243695735931 -- aux loss:  0
# the_last_loss:  0.0
# running_loss_val:  1.1798992156982422
# validating: epoch:  10  loss:  1.1798992156982422
# The current loss: 1.1798992156982422
# the_last_loss: 0.0
# trigger times: 1
# sum mask2 - L1:  tensor(4877, device='cuda:0')
# sum mask2 - L2:  tensor(7502, device='cuda:0')
# sum mask2 - L3:  tensor(150, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1123, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2498, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(50, device='cuda:0')
# training: epoch:  11  loss:  100.50520384311676 -- aux loss:  0
# training: epoch:  12  loss:  100.31394189596176 -- aux loss:  0
# training: epoch:  13  loss:  100.49201440811157 -- aux loss:  0
# training: epoch:  14  loss:  100.48342877626419 -- aux loss:  0
# training: epoch:  15  loss:  100.46000272035599 -- aux loss:  0
# training: epoch:  16  loss:  100.27656257152557 -- aux loss:  0
# training: epoch:  17  loss:  100.23266994953156 -- aux loss:  0
# training: epoch:  18  loss:  100.28934019804001 -- aux loss:  0
# training: epoch:  19  loss:  100.18099749088287 -- aux loss:  0
# training: epoch:  20  loss:  100.09394472837448 -- aux loss:  0
# the_last_loss:  1.1798992156982422
# running_loss_val:  1.166131615638733
# validating: epoch:  20  loss:  1.166131615638733
# The current loss: 1.166131615638733
# the_last_loss: 1.1798992156982422
# trigger times: 0
# sum mask2 - L1:  tensor(4877, device='cuda:0')
# sum mask2 - L2:  tensor(7502, device='cuda:0')
# sum mask2 - L3:  tensor(150, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1123, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2498, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(50, device='cuda:0')
# training: epoch:  21  loss:  100.18539917469025 -- aux loss:  0
# training: epoch:  22  loss:  100.29397410154343 -- aux loss:  0
# training: epoch:  23  loss:  100.05033057928085 -- aux loss:  0
# training: epoch:  24  loss:  100.0206104516983 -- aux loss:  0
# training: epoch:  25  loss:  100.0856261253357 -- aux loss:  0
# training: epoch:  26  loss:  99.95072013139725 -- aux loss:  0
# training: epoch:  27  loss:  99.97809106111526 -- aux loss:  0
# training: epoch:  28  loss:  99.98608630895615 -- aux loss:  0
# training: epoch:  29  loss:  99.93956530094147 -- aux loss:  0
# training: epoch:  30  loss:  99.95152008533478 -- aux loss:  0
# the_last_loss:  1.166131615638733
# running_loss_val:  0.4266720414161682
# validating: epoch:  30  loss:  0.4266720414161682
# The current loss: 0.4266720414161682
# the_last_loss: 1.166131615638733
# trigger times: 0
# sum mask2 - L1:  tensor(4877, device='cuda:0')
# sum mask2 - L2:  tensor(7502, device='cuda:0')
# sum mask2 - L3:  tensor(150, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1123, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2498, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(50, device='cuda:0')
# training: epoch:  31  loss:  99.8888384103775 -- aux loss:  0
# training: epoch:  32  loss:  99.7574674487114 -- aux loss:  0
# training: epoch:  33  loss:  99.80933612585068 -- aux loss:  0
# training: epoch:  34  loss:  100.06824243068695 -- aux loss:  0
# training: epoch:  35  loss:  99.72268134355545 -- aux loss:  0
# training: epoch:  36  loss:  99.9596815109253 -- aux loss:  0
# training: epoch:  37  loss:  99.8198601603508 -- aux loss:  0
# training: epoch:  38  loss:  99.73413175344467 -- aux loss:  0
# training: epoch:  39  loss:  99.6767475605011 -- aux loss:  0
# training: epoch:  40  loss:  99.66085308790207 -- aux loss:  0
# the_last_loss:  0.4266720414161682
# running_loss_val:  0.8302325010299683
# validating: epoch:  40  loss:  0.8302325010299683
# The current loss: 0.8302325010299683
# the_last_loss: 0.4266720414161682
# trigger times: 1
# sum mask2 - L1:  tensor(4877, device='cuda:0')
# sum mask2 - L2:  tensor(7502, device='cuda:0')
# sum mask2 - L3:  tensor(150, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1123, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2498, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(50, device='cuda:0')
# training: epoch:  41  loss:  99.75906348228455 -- aux loss:  0
# training: epoch:  42  loss:  99.72608482837677 -- aux loss:  0
# training: epoch:  43  loss:  99.67986297607422 -- aux loss:  0
# training: epoch:  44  loss:  99.58592563867569 -- aux loss:  0
# training: epoch:  45  loss:  99.50750625133514 -- aux loss:  0
# training: epoch:  46  loss:  99.70274847745895 -- aux loss:  0
# training: epoch:  47  loss:  99.62080425024033 -- aux loss:  0
# training: epoch:  48  loss:  99.59363448619843 -- aux loss:  0
# training: epoch:  49  loss:  99.48486733436584 -- aux loss:  0
# training: epoch:  50  loss:  99.72807532548904 -- aux loss:  0
# the_last_loss:  0.8302325010299683
# running_loss_val:  0.7685011625289917
# validating: epoch:  50  loss:  0.7685011625289917
# The current loss: 0.7685011625289917
# the_last_loss: 0.8302325010299683
# trigger times: 0
# sum mask2 - L1:  tensor(4877, device='cuda:0')
# sum mask2 - L2:  tensor(7502, device='cuda:0')
# sum mask2 - L3:  tensor(150, device='cuda:0')
# sum mask1 - L1 (aux):  tensor(1123, device='cuda:0')
# sum mask1 - L2 (aux):  tensor(2498, device='cuda:0')
# sum mask1 - L3 (aux):  tensor(50, device='cuda:0')
# training: epoch:  51  loss:  99.55295050144196 -- aux loss:  0
# training: epoch:  52  loss:  99.43252855539322 -- aux loss:  0
# training: epoch:  53  loss:  99.44677430391312 -- aux loss:  0
# training: epoch:  54  loss:  99.50393402576447 -- aux loss:  0
# training: epoch:  55  loss:  99.41339635848999 -- aux loss:  0
# training: epoch:  56  loss:  99.40971726179123 -- aux loss:  0
# training: epoch:  57  loss:  99.46535193920135 -- aux loss:  0
# training: epoch:  58  loss:  99.4930734038353 -- aux loss:  0

# %%
results = []

num_classes = 2
learning_rate = 0.005
samples = 3000
epsilon=0
#for epsilon in [0.1, 0.05, 0.025, 0.15]:
for batch_size in [256]:
    for hidden_size in [100]:
        for aux_loss_activated in [True, False]:
            for EPS1 in [0.025]:
                for n in [50000]:
                    for opt in [1]:
                        for t in range(10):
                            train_dataset, test_dataset = ut.load_files(dataset=1)
                            test_dataseta  = RRc_test[train_dataset.columns]
                            test_dataset = pd.concat([train_dataset[train_dataset.label=='ClassB'], test_dataseta])
                            test_dataset['random'] = np.random.random(test_dataset.shape[0])
                            test_dataset = test_dataset.sort_values('random')
                            del test_dataset['random']
                            input_size = train_dataset.shape[1]-1
                            
                            train_dataset, test_dataset = ut.delete_outliers(train_dataset, test_dataset)
                            if n < 50000:
                                train_dataset = ut.down_sampling(train_dataset)
                                train_dataset = train_dataset.sample(n)
                            else: 
                                trainig_dataset_a = train_dataset[train_dataset.label=='ClassA']
                                n2 = n - trainig_dataset_a.shape[0]
                                trainig_dataset_b = train_dataset[~(train_dataset.label=='ClassA')].sample(n2)
                                train_dataset = pd.concat([trainig_dataset_a, trainig_dataset_b])
                            
                            train_dataset = ut.sort_columns(train_dataset)
                            test_dataset = ut.sort_columns(test_dataset)
                            test_dataset_pred = test_dataset.copy()
                            train_dataset_pred = train_dataset.copy()

                            data_prior = ut.generate_samples_2D(samples, train_dataset, distribution='gaussian')
                            if train_dataset[train_dataset.label=='ClassB'].shape[0] >= samples:
                                samples_prior = samples 
                            else: 
                                samples_prior = train_dataset[train_dataset.label=='ClassB'].shape[0] 

                            data_prior = pd.concat([data_prior, train_dataset[train_dataset.label=='ClassB'].sample(samples_prior)])


                            train_dataset, test_dataset, data_prior = ut.normalize(train_dataset, test_dataset, data_prior)

                            train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.2)

                            train_dataset_prior, val_dataset_prior = train_test_split(data_prior, test_size=0.2)
                            _, _, train_target_prior, train_loader_prior = ut.get_tensors(train_dataset_prior, batch_size)
                            _, _, val_target_prior, val_loader_prior     = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, train_target, train_loader             = ut.get_tensors(train_dataset, batch_size)
                            _, _, train_target_pred, train_loader_pred   = ut.get_tensors(train_dataset_pred, batch_size)
                            _, _, val_target, val_loader                 = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, test_target, test_loader               = ut.get_tensors(test_dataset, batch_size)
                            _, _, test_target_pred, test_loader_pred     = ut.get_tensors(test_dataset_pred, batch_size)

                            net = Net(input_size, hidden_size, hidden_size, num_classes)
                            net.cuda()

                            hist_val, hist_train, _ = nn.train(net, train_loader, train_loader_prior, val_loader, test_loader,
                            EPS1, learning_rate, input_size, aux_loss_activated=aux_loss_activated, model_number=t, size=n)

                            acc_train, recall_train, f1_train = nn.get_results(net, train_loader, input_size)
                            acc_test, recall_test, f1_test  = nn.get_results(net, test_loader, input_size)
                            roc_train = nn.get_roc_curve(net, train_loader, input_size)
                            roc_test = nn.get_roc_curve(net, test_loader, input_size)
                            results.append([acc_train, acc_test,recall_train, recall_test, f1_train, f1_test, roc_train, roc_test, epsilon, batch_size, hidden_size, aux_loss_activated, EPS1, n, opt])

                            pd.DataFrame(results, columns=['acc_train', 'acc_test','recall_train', 'recall_test','f1_train', 'f1_test', 
                                   'roc_train', 'roc_test', 'epsilon', 'batch_size', 'hidden_size',
                             'aux_loss_activated', 'EPS1', 'n', 'opt']).to_csv('RRc_17_01_2023_subclasses_gaussian2d.csv')

# %%
results = []

num_classes = 2
learning_rate = 0.005
samples = 3000
epsilon=0
#for epsilon in [0.1, 0.05, 0.025, 0.15]:
for batch_size in [256]:
    for hidden_size in [100]:
        for aux_loss_activated in [True, False]:
            for EPS1 in [0.025]:
                for n in [50000]:
                    for opt in [1]:
                        for t in range(10):
                            train_dataset, test_dataset = ut.load_files(dataset=1)
                            test_dataseta  = RRd_test[train_dataset.columns]
                            test_dataset = pd.concat([train_dataset[train_dataset.label=='ClassB'], test_dataseta])
                            test_dataset['random'] = np.random.random(test_dataset.shape[0])
                            test_dataset = test_dataset.sort_values('random')
                            del test_dataset['random']
                            input_size = train_dataset.shape[1]-1
                            
                            
                            train_dataset, test_dataset = ut.delete_outliers(train_dataset, test_dataset)
                            if n < 50000:
                                train_dataset = ut.down_sampling(train_dataset)
                                train_dataset = train_dataset.sample(n)
                            else: 
                                trainig_dataset_a = train_dataset[train_dataset.label=='ClassA']
                                n2 = n - trainig_dataset_a.shape[0]
                                trainig_dataset_b = train_dataset[~(train_dataset.label=='ClassA')].sample(n2)
                                train_dataset = pd.concat([trainig_dataset_a, trainig_dataset_b])
                            
                            train_dataset = ut.sort_columns(train_dataset)
                            test_dataset = ut.sort_columns(test_dataset)
                            test_dataset_pred = test_dataset.copy()
                            train_dataset_pred = train_dataset.copy()

                            data_prior = ut.generate_samples_2D(samples, train_dataset, distribution='gaussian')
                            if train_dataset[train_dataset.label=='ClassB'].shape[0] >= samples:
                                samples_prior = samples 
                            else: 
                                samples_prior = train_dataset[train_dataset.label=='ClassB'].shape[0] 

                            data_prior = pd.concat([data_prior, train_dataset[train_dataset.label=='ClassB'].sample(samples_prior)])


                            train_dataset, test_dataset, data_prior = ut.normalize(train_dataset, test_dataset, data_prior)

                            train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.2)

                            train_dataset_prior, val_dataset_prior = train_test_split(data_prior, test_size=0.2)
                            _, _, train_target_prior, train_loader_prior = ut.get_tensors(train_dataset_prior, batch_size)
                            _, _, val_target_prior, val_loader_prior     = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, train_target, train_loader             = ut.get_tensors(train_dataset, batch_size)
                            _, _, train_target_pred, train_loader_pred   = ut.get_tensors(train_dataset_pred, batch_size)
                            _, _, val_target, val_loader                 = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, test_target, test_loader               = ut.get_tensors(test_dataset, batch_size)
                            _, _, test_target_pred, test_loader_pred     = ut.get_tensors(test_dataset_pred, batch_size)

                            net = Net(input_size, hidden_size, hidden_size, num_classes)
                            net.cuda()

                            hist_val, hist_train, _ = nn.train(net, train_loader, train_loader_prior, val_loader, test_loader,
                            EPS1, learning_rate, input_size, aux_loss_activated=aux_loss_activated, model_number=t, size=n)

                            acc_train, recall_train, f1_train = nn.get_results(net, train_loader, input_size)
                            acc_test, recall_test, f1_test  = nn.get_results(net, test_loader, input_size)
                            roc_train = nn.get_roc_curve(net, train_loader, input_size)
                            roc_test = nn.get_roc_curve(net, test_loader, input_size)
                            results.append([acc_train, acc_test,recall_train, recall_test, f1_train, f1_test, roc_train, roc_test, epsilon, batch_size, hidden_size, aux_loss_activated, EPS1, n, opt])

                            pd.DataFrame(results, columns=['acc_train', 'acc_test','recall_train', 'recall_test','f1_train', 'f1_test', 
                                   'roc_train', 'roc_test', 'epsilon', 'batch_size', 'hidden_size',
                             'aux_loss_activated', 'EPS1', 'n', 'opt']).to_csv('RRd_17_01_2023_subclasses_gaussian2d.csv')

# %%
results = []

num_classes = 2
learning_rate = 0.005
samples = 3000
epsilon=0
#for epsilon in [0.1, 0.05, 0.025, 0.15]:
for batch_size in [256]:
    for hidden_size in [100]:
        for aux_loss_activated in [True, False]:
            for EPS1 in [0.025]:
                for n in [50000]:
                    for opt in [1]:
                        for t in range(10):
                            
                            train_dataset, test_dataset = ut.load_files(dataset=1)
                            test_dataseta  = RRe_test[train_dataset.columns]
                            test_dataset = pd.concat([train_dataset[train_dataset.label=='ClassB'], test_dataseta])
                            test_dataset['random'] = np.random.random(test_dataset.shape[0])
                            test_dataset = test_dataset.sort_values('random')
                            del test_dataset['random']
                            input_size = train_dataset.shape[1]-1
                            
                            input_size = train_dataset.shape[1]-1
                            train_dataset, test_dataset = ut.delete_outliers(train_dataset, test_dataset)
                            if n < 50000:
                                train_dataset = ut.down_sampling(train_dataset)
                                train_dataset = train_dataset.sample(n)
                            else: 
                                trainig_dataset_a = train_dataset[train_dataset.label=='ClassA']
                                n2 = n - trainig_dataset_a.shape[0]
                                trainig_dataset_b = train_dataset[~(train_dataset.label=='ClassA')].sample(n2)
                                train_dataset = pd.concat([trainig_dataset_a, trainig_dataset_b])
                            
                            train_dataset = ut.sort_columns(train_dataset)
                            test_dataset = ut.sort_columns(test_dataset)
                            test_dataset_pred = test_dataset.copy()
                            train_dataset_pred = train_dataset.copy()

                            data_prior = ut.generate_samples_2D(samples, train_dataset, distribution='gaussian')
                            if train_dataset[train_dataset.label=='ClassB'].shape[0] >= samples:
                                samples_prior = samples 
                            else: 
                                samples_prior = train_dataset[train_dataset.label=='ClassB'].shape[0] 

                            data_prior = pd.concat([data_prior, train_dataset[train_dataset.label=='ClassB'].sample(samples_prior)])


                            train_dataset, test_dataset, data_prior = ut.normalize(train_dataset, test_dataset, data_prior)

                            train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.2)

                            train_dataset_prior, val_dataset_prior = train_test_split(data_prior, test_size=0.2)
                            _, _, train_target_prior, train_loader_prior = ut.get_tensors(train_dataset_prior, batch_size)
                            _, _, val_target_prior, val_loader_prior     = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, train_target, train_loader             = ut.get_tensors(train_dataset, batch_size)
                            _, _, train_target_pred, train_loader_pred   = ut.get_tensors(train_dataset_pred, batch_size)
                            _, _, val_target, val_loader                 = ut.get_tensors(val_dataset_prior, batch_size)
                            _, _, test_target, test_loader               = ut.get_tensors(test_dataset, batch_size)
                            _, _, test_target_pred, test_loader_pred     = ut.get_tensors(test_dataset_pred, batch_size)

                            net = Net(input_size, hidden_size, hidden_size, num_classes)
                            net.cuda()

                            hist_val, hist_train, _ = nn.train(net, train_loader, train_loader_prior, val_loader, test_loader,
                            EPS1, learning_rate, input_size, aux_loss_activated=aux_loss_activated, model_number=t, size=n)

                            acc_train, recall_train, f1_train = nn.get_results(net, train_loader, input_size)
                            acc_test, recall_test, f1_test  = nn.get_results(net, test_loader, input_size)
                            roc_train = nn.get_roc_curve(net, train_loader, input_size)
                            roc_test = nn.get_roc_curve(net, test_loader, input_size)
                            results.append([acc_train, acc_test,recall_train, recall_test, f1_train, f1_test, roc_train, roc_test, epsilon, batch_size, hidden_size, aux_loss_activated, EPS1, n, opt])

                            pd.DataFrame(results, columns=['acc_train', 'acc_test','recall_train', 'recall_test','f1_train', 'f1_test', 
                                   'roc_train', 'roc_test', 'epsilon', 'batch_size', 'hidden_size',
                             'aux_loss_activated', 'EPS1', 'n', 'opt']).to_csv('RRe_17_01_2023_subclasses_gaussian2d.csv')

# %%
n = 50000
samples = 3000
for i in range(0,30):

    net = Net(input_size, hidden_size, hidden_size, num_classes)
    net.load_state_dict(dict(torch.load('model_'+str(i)+'_False_50000.pt'))['model'+str(i)+'_False_50000'])
    net.eval()
    net.cuda()

    train_dataset , test_dataset = ut.load_files(dataset=1)
    input_size = test_dataset.shape[1]-1
    train_dataset, test_dataset = ut.delete_outliers(train_dataset, test_dataset)
    
    trainig_dataset_a = train_dataset[train_dataset.label=='ClassA']
    n2 = n - trainig_dataset_a.shape[0]
    trainig_dataset_b = train_dataset[~(train_dataset.label=='ClassA')].sample(n2)
    train_dataset = pd.concat([trainig_dataset_a, trainig_dataset_b])
    test_dataset = ut.sort_columns(test_dataset)
    test_dataset_pred = test_dataset.copy()
    data_prior = ut.generate_samples_2D(samples, train_dataset, distribution='gaussian')
    if train_dataset[train_dataset.label=='ClassB'].shape[0] >= samples:
        samples_prior = samples 
    else: 
        samples_prior = train_dataset[train_dataset.label=='ClassB'].shape[0] 

    data_prior = pd.concat([data_prior, train_dataset[train_dataset.label=='ClassB'].sample(samples_prior)])
    train_dataset, test_dataset, data_prior = ut.normalize(train_dataset, test_dataset, data_prior)

    _, _, test_target, test_loader               = ut.get_tensors(test_dataset, batch_size)
    _, _, test_target_pred, test_loader_pred     = ut.get_tensors(test_dataset_pred, batch_size)

    acc_test, recall_test, f1_test  = nn.get_results(net, test_loader, input_size)
    roc_test = nn.get_roc_curve(net, test_loader, input_size)

# %%
RRab_test
